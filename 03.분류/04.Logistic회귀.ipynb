# %% [markdown]
# ### 로지스틱 회귀(Logistic Regression) - 분류

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# - sigmoid 함수

# %%
def sigmoid(x, a=1, b=0):
    return (1. / (1+np.exp(-a * (x-b))))

# %%
xs = np.linspace(-5, 5, 1000)
ys = sigmoid(xs)
plt.plot(xs, ys, label='sigmoid')
plt.plot(xs, ys*(1-ys), label='derivative')
plt.title('Sigmoid function')
plt.yticks([0., 0.5, 1])
plt.grid(), plt.legend()
plt.show()

# %%
# a 값에 따른 변화
y3 = sigmoid(xs, a=3)
y_half = sigmoid(xs, a=0.5)
plt.plot(xs, ys, label='a=1')
plt.plot(xs, y3, label='a=3')
plt.plot(xs, y_half, label='a=0.5')
plt.title('Sigmoid function')
plt.yticks([0., 0.5, 1])
plt.grid(), plt.legend()
plt.show()

# %%
# b값에 따른 변화
y_plus2 = sigmoid(xs, b=2)
y_minus2 = sigmoid(xs, b=-2)
plt.plot(xs, y_plus2, label='b=2')
plt.plot(xs, ys, label='b=0')
plt.plot(xs, y_minus2, label='b=-2')
plt.title('Sigmoid function')
plt.yticks([0., 0.5, 1])
plt.grid(), plt.legend()
plt.show()

# %% [markdown]
# - 이진 분류

# %%
import pandas as pd
pima = pd.read_csv('../data/pima-indians-diabetes.csv', skiprows=9, header=None)
pima.columns=['P', 'G', 'BP', 'S', 'I', 'BMI', 'D', 'Age', 'Target']
pima.head()
# Out:
#    P    G  BP   S    I   BMI      D  Age  Target
# 0  6  148  72  35    0  33.6  0.627   50       1
# 1  1   85  66  29    0  26.6  0.351   31       0
# 2  8  183  64   0    0  23.3  0.672   32       1
# 3  1   89  66  23   94  28.1  0.167   21       0
# 4  0  137  40  35  168  43.1  2.288   33       1

# %%
y = pima.Target.values
X = pima.iloc[:, :-1].values

# %%
# 로지스틱 회귀를 사용하려면 데이터 표준화/정규화 필요
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X_std, y, test_size=0.2, stratify=y, random_state=2023
)

# %%
from sklearn.linear_model import LogisticRegression
lrc = LogisticRegression(random_state=2023)
lrc.get_params()
# Out:
# {'C': 1.0,
#  'class_weight': None,
#  'dual': False,
#  'fit_intercept': True,
#  'intercept_scaling': 1,
#  'l1_ratio': None,
#  'max_iter': 100,
#  'multi_class': 'auto',
#  'n_jobs': None,
#  'penalty': 'l2',
#  'random_state': 2023,
#  'solver': 'lbfgs',
#  'tol': 0.0001,
#  'verbose': 0,
#  'warm_start': False}

# %%
lrc.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=2023)

# %%
lrc.score(X_test, y_test)
# Out:
# 0.7987012987012987

# %%
# 선형회귀의 가중치(계수)
lrc.coef_.round(2)
# Out:
# array([[ 0.44,  1.11, -0.22,  0.06, -0.22,  0.67,  0.22,  0.14]])

# %%
# 선형회귀의 바이어스(절편)
lrc.intercept_
# Out:
# array([-0.83697953])

# %%
X_test[0], y_test[0]
# Out:
# (array([-8.44885053e-01, -3.78365371e+00, -5.71502470e-02,  9.07269925e-01,
#         -6.92890572e-01,  9.41978774e-04, -2.50296268e-01, -9.56461683e-01]),
#  0)

# %%
# X_test[0]이 1이 될 확률, sigmoid 함수 적용 전 값
val = np.dot(lrc.coef_, X_test[0]) + lrc.intercept_
val
# Out:
# array([-5.36681519])

# %%
# sigmoid 함수 적용
sigmoid(val)
# Out:
# array([0.00464728])

# %%
lrc.predict_proba(X_test[:1])
# Out:
# array([[0.99535272, 0.00464728]])

# %% [markdown]
# - 다중 분류

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
iris_std = StandardScaler().fit_transform(iris.data)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    iris_std, iris.target, test_size=0.2, stratify=iris.target, random_state=2023
)

# %%
lrc = LogisticRegression(random_state=2023)
lrc.fit(X_train, y_train)
lrc.score(X_test, y_test)
# Out:
# 0.9666666666666667

# %%
lrc.predict_proba(X_test)[:1]
# Out:
# array([[3.30286696e-05, 7.71018326e-03, 9.92256788e-01]])

# %%
lrc.coef_.round(2), lrc.intercept_
# Out:
# (array([[-1.05,  1.08, -1.78, -1.66],
#         [ 0.58, -0.41, -0.39, -0.73],
#         [ 0.47, -0.67,  2.17,  2.39]]),
#  array([-0.17112899,  1.8490486 , -1.67791961]))

# %%
val = np.dot(lrc.coef_, X_test[0]) + lrc.intercept_
val
# Out:
# array([-5.25442751,  0.19849377,  5.05593374])

# %%
sigmoid(val)
# Out:
# array([0.00519718, 0.54946115, 0.99366892])

# %%
def softmax(x):
    return np.exp(x) / np.sum(np.exp(x))

# %%
softmax(np.array([0.1, 1, 2]))
# Out:
# array([0.09856589, 0.24243297, 0.65900114])

# %%
# 다중 분류에서 predict_proba() 값은 softmax() 적용값
softmax(val)
# Out:
# array([3.30286696e-05, 7.71018326e-03, 9.92256788e-01])

# %%
lrc.predict_proba(X_test[:1])
# Out:
# array([[3.30286696e-05, 7.71018326e-03, 9.92256788e-01]])
